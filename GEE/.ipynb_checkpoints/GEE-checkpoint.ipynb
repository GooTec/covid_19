# %%
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing

def standardize(col_dat):
    col_dat = col_dat.dropna()
    std_col = ( col_dat - np.mean(col_dat) )/ np.std(col_dat)
    return std_col

# %%
data = pd.read_csv('/data/member/twgoo/COVID-19/trajectory_analysis/oxford_globa.csv', index_col=0)

# %%
pre_country_code = set(data['CountryCode'])
print("Total number of countries :",len(pre_country_code))
# Out:
# Total number of countries : 40

# %%
data.describe()
# Out:
#               Days  C1_School closing  C2_Workplace closing  \
# count  7240.000000        4060.000000           3967.000000
# mean     91.000000           0.880419              0.746471
# std      52.253011           0.165140              0.181796
# min       1.000000           0.250000              0.250000
# 25%      46.000000           0.750000              0.500000
# 50%      91.000000           1.000000              0.750000
# 75%     136.000000           1.000000              0.750000
# max     181.000000           1.000000              1.000000
#
#        C3_Cancel public events  C4_Restrictions on gatherings  \
# count              4267.000000                    3597.000000
# mean                  0.875713                       0.838477
# std                   0.178679                       0.161089
# min                   0.333333                       0.200000
# 25%                   0.666667                       0.800000
# 50%                   1.000000                       0.800000
# 75%                   1.000000                       1.000000
# max                   1.000000                       1.000000
#
#        C5_Close public transport  C6_Stay at home requirements  \
# count                2310.000000                   3459.000000
# mean                    0.691631                      0.613544
# std                     0.207881                      0.167888
# min                     0.333333                      0.250000
# 25%                     0.666667                      0.500000
# 50%                     0.666667                      0.500000
# 75%                     0.666667                      0.750000
# max                     1.000000                      1.000000
#
#        C7_Restrictions on internal movement  C8_International travel controls  \
# count                           3572.000000                       6913.000000
# mean                               0.768944                          0.548040
# std                                0.179689                          0.426912
# min                                0.333333                          0.000000
# 25%                                0.666667                          0.000000
# 50%                                0.666667                          0.600000
# 75%                                1.000000                          1.000000
# max                                1.000000                          1.200000
#
#        E1_Income support  E2_Debt/contract relief  E3_Fiscal measures  \
# count        3070.000000              6922.000000         6879.000000
# mean            0.689902                 0.348021            0.231110
# std             0.195815                 0.426360            1.448816
# min             0.333333                 0.000000           -0.124939
# 25%             0.666667                 0.000000            0.000000
# 50%             0.666667                 0.000000            0.000000
# 75%             0.666667                 1.000000            0.000000
# max             1.000000                 1.000000           12.291724
#
#        E4_International support  H1_Public information campaigns  \
# count               6903.000000                      5313.000000
# mean                   0.039852                         0.971265
# std                    0.557333                         0.095773
# min                    0.000000                         0.333333
# 25%                    0.000000                         1.000000
# 50%                    0.000000                         1.000000
# 75%                    0.000000                         1.000000
# max                   11.921350                         1.000000
#
#        H2_Testing policy  H3_Contact tracing  \
# count        6902.000000         6914.000000
# mean            0.419009            0.509257
# std             0.331129            0.395879
# min             0.000000            0.000000
# 25%             0.000000            0.000000
# 50%             0.333333            0.500000
# 75%             0.666667            1.000000
# max             1.000000            1.000000
#
#        H4_Emergency investment in healthcare  H5_Investment in vaccines  \
# count                            6895.000000                6891.000000
# mean                                0.130329                   0.044373
# std                                 0.979893                   0.550077
# min                                -1.522879                   0.000000
# 25%                                 0.000000                   0.000000
# 50%                                 0.000000                   0.000000
# 75%                                 0.000000                   0.000000
# max                                11.384533                   9.143015
#
#        ConfirmedCases  DailyConfirmed
# count    6.658000e+03     6609.000000
# mean     5.332776e+04     1158.799667
# std      1.916719e+05     4055.068217
# min      0.000000e+00    -2461.000000
# 25%      5.250000e+00        0.000000
# 50%      4.685000e+03       69.000000
# 75%      2.965050e+04      533.000000
# max      2.510323e+06    54771.000000

# %%
std_data = data.iloc[:,2:-2].apply(lambda x : standardize(x), axis=0)

# %%
std_data
# Out:
#       C1_School closing  C2_Workplace closing  C3_Cancel public events  \
# 1                   NaN                   NaN                      NaN
# 2                   NaN                   NaN                      NaN
# 3                   NaN                   NaN                      NaN
# 4                   NaN                   NaN                      NaN
# 5                   NaN                   NaN                      NaN
# ...                 ...                   ...                      ...
# 7232          -0.789846             -1.355925                -1.170089
# 7233          -0.789846             -1.355925                -1.170089
# 7234          -0.789846             -1.355925                -1.170089
# 7235          -0.789846             -1.355925                -1.170089
# 7236                NaN                   NaN                      NaN
#
#       C4_Restrictions on gatherings  C5_Close public transport  \
# 1                               NaN                        NaN
# 2                               NaN                        NaN
# 3                               NaN                        NaN
# 4                               NaN                        NaN
# 5                               NaN                        NaN
# ...                             ...                        ...
# 7232                      -0.238886                  -1.723939
# 7233                      -0.238886                  -1.723939
# 7234                      -0.238886                  -1.723939
# 7235                      -0.238886                  -1.723939
# 7236                            NaN                        NaN
#
#       C6_Stay at home requirements  C7_Restrictions on internal movement  \
# 1                              NaN                                   NaN
# 2                              NaN                                   NaN
# 3                              NaN                                   NaN
# 4                              NaN                                   NaN
# 5                              NaN                                   NaN
# ...                            ...                                   ...
# 7232                      -0.67641                             -0.569267
# 7233                      -0.67641                             -0.569267
# 7234                      -0.67641                             -0.569267
# 7235                      -0.67641                             -0.569267
# 7236                           NaN                                   NaN
#
#       C8_International travel controls  E1_Income support  \
# 1                            -1.283825                NaN
# 2                            -1.283825                NaN
# 3                            -1.283825                NaN
# 4                            -1.283825                NaN
# 5                            -1.283825                NaN
# ...                                ...                ...
# 7232                          1.058750          -0.118681
# 7233                          1.058750          -0.118681
# 7234                          1.058750          -0.118681
# 7235                          1.058750          -0.118681
# 7236                               NaN                NaN
#
#       E2_Debt/contract relief  E3_Fiscal measures  E4_International support  \
# 1                   -0.816320           -0.159528                  -0.07151
# 2                   -0.816320           -0.159528                  -0.07151
# 3                   -0.816320           -0.159528                  -0.07151
# 4                   -0.816320           -0.159528                  -0.07151
# 5                   -0.816320           -0.159528                  -0.07151
# ...                       ...                 ...                       ...
# 7232                 0.356483           -0.159528                  -0.07151
# 7233                 0.356483           -0.159528                  -0.07151
# 7234                 0.356483           -0.159528                  -0.07151
# 7235                 0.356483           -0.159528                  -0.07151
# 7236                      NaN                 NaN                       NaN
#
#       H1_Public information campaigns  H2_Testing policy  H3_Contact tracing  \
# 1                                 NaN          -1.265486           -1.286487
# 2                                 NaN          -1.265486           -1.286487
# 3                                 NaN          -1.265486           -1.286487
# 4                                 NaN          -1.265486           -1.286487
# 5                                 NaN          -1.265486           -1.286487
# ...                               ...                ...                 ...
# 7232                         0.300055           1.754703           -0.023384
# 7233                         0.300055           1.754703           -0.023384
# 7234                         0.300055           1.754703           -0.023384
# 7235                         0.300055           1.754703           -0.023384
# 7236                         0.300055           1.754703           -0.023384
#
#       H4_Emergency investment in healthcare  H5_Investment in vaccines
# 1                                 -0.133013                  -0.080674
# 2                                 -0.133013                  -0.080674
# 3                                 -0.133013                  -0.080674
# 4                                 -0.133013                  -0.080674
# 5                                 -0.133013                  -0.080674
# ...                                     ...                        ...
# 7232                              -0.133013                  -0.080674
# 7233                              -0.133013                  -0.080674
# 7234                              -0.133013                  -0.080674
# 7235                              -0.133013                  -0.080674
# 7236                              -0.133013                  -0.080674
#
# [6974 rows x 17 columns]

# %% [markdown]
# # Data pre-processing
# ## Problems
# 1. Negative new confirmers
# 2. Days start from 2020-01-01 for all countries

# %%
for country in pre_country_code : 
    sub_data = data[data['CountryCode'] == country]
    
    others_data = data[data['CountryCode'] != country]
#     if min(sub_data['DailyConfirmed'].dropna()) < 0 : 
# #     if min(sub_data['DailyConfirmed'].dropna()) < 0 or max(sub_data['DailyConfirmed'].dropna()) > 680 :
#         data = data[data['CountryCode'] != country]
#     else :
    print(min(sub_data['DailyConfirmed']), max(sub_data['DailyConfirmed']) )
    first_day = 0 
    for i in range(len(sub_data)):
        if sub_data.iloc[i,-1] > 0 :
            first_day = i
            break
    sub_data = sub_data.iloc[first_day:]
    for i in range(len(sub_data)):
        sub_data.iloc[i,1] = i + 1
    data = pd.concat([sub_data, others_data], axis=0)
# Out:
# nan nan
# nan nan
# 0.0 5275.0
# 0.0 1385.0
# 0.0 1401.0
# 0.0 11656.0
# 0.0 6294.0
# 0.0 1143.0
# 0.0 2319.0
# -148.0 6557.0
# 0.0 234.0
# -2461.0 11536.0
# 0.0 1426.0
# 0.0 1390.0
# 0.0 267.0
# 0.0 899.0
# 0.0 425.0
# 0.0 6825.0
# 0.0 54771.0
# 0.0 48529.0
# 0.0 390.0
# 0.0 1335.0
# nan nan
# 0.0 15141.0
# 0.0 2760.0
# 0.0 296.0
# 0.0 909.0
# nan nan
# -713.0 9181.0
# 0.0 611.0
# 0.0 1063.0
# nan nan
# 0.0 2889.0
# 0.0 1169.0
# nan nan
# 0.0 263.0
# 0.0 6288.0
# -525.0 8719.0
# nan nan
# 0.0 408.0

# %%
data.describe()
# Out:
#               Days  C1_School closing  C2_Workplace closing  \
# count  5457.000000        4032.000000           3947.000000
# mean     70.162177           0.881324              0.747720
# std      41.868045           0.165353              0.181405
# min       1.000000           0.250000              0.250000
# 25%      35.000000           0.750000              0.500000
# 50%      69.000000           1.000000              0.750000
# 75%     103.000000           1.000000              0.875000
# max     181.000000           1.000000              1.000000
#
#        C3_Cancel public events  C4_Restrictions on gatherings  \
# count              4263.000000                    3593.000000
# mean                  0.875909                       0.838742
# std                   0.178648                       0.160982
# min                   0.333333                       0.200000
# 25%                   0.666667                       0.800000
# 50%                   1.000000                       0.800000
# 75%                   1.000000                       1.000000
# max                   1.000000                       1.000000
#
#        C5_Close public transport  C6_Stay at home requirements  \
# count                2310.000000                   3455.000000
# mean                    0.691631                      0.613676
# std                     0.207881                      0.167940
# min                     0.333333                      0.250000
# 25%                     0.666667                      0.500000
# 50%                     0.666667                      0.500000
# 75%                     0.666667                      0.750000
# max                     1.000000                      1.000000
#
#        C7_Restrictions on internal movement  C8_International travel controls  \
# count                           3571.000000                       5130.000000
# mean                               0.768972                          0.718830
# std                                0.179706                          0.352879
# min                                0.333333                          0.000000
# 25%                                0.666667                          0.600000
# 50%                                0.666667                          0.800000
# 75%                                1.000000                          1.000000
# max                                1.000000                          1.200000
#
#        E1_Income support  E2_Debt/contract relief  E3_Fiscal measures  \
# count        3070.000000              5139.000000         5096.000000
# mean            0.689902                 0.468768            0.311971
# std             0.195815                 0.433880            1.675831
# min             0.333333                 0.000000           -0.124939
# 25%             0.666667                 0.000000            0.000000
# 50%             0.666667                 0.500000            0.000000
# 75%             0.666667                 1.000000            0.000000
# max             1.000000                 1.000000           12.291724
#
#        E4_International support  H1_Public information campaigns  \
# count               5120.000000                      4801.000000
# mean                   0.051629                         0.986045
# std                    0.637957                         0.070149
# min                    0.000000                         0.333333
# 25%                    0.000000                         1.000000
# 50%                    0.000000                         1.000000
# 75%                    0.000000                         1.000000
# max                   11.921350                         1.000000
#
#        H2_Testing policy  H3_Contact tracing  \
# count        5119.000000         5131.000000
# mean            0.537084            0.654161
# std             0.285951            0.327599
# min             0.000000            0.000000
# 25%             0.333333            0.500000
# 50%             0.666667            0.500000
# 75%             0.666667            1.000000
# max             1.000000            1.000000
#
#        H4_Emergency investment in healthcare  H5_Investment in vaccines  \
# count                            5112.000000                5108.000000
# mean                                0.173534                   0.057517
# std                                 1.129136                   0.627196
# min                                -1.522879                   0.000000
# 25%                                 0.000000                   0.000000
# 50%                                 0.000000                   0.000000
# 75%                                 0.000000                   0.000000
# max                                11.384533                   9.143015
#
#        ConfirmedCases  DailyConfirmed
# count    5.344000e+03     5308.000000
# mean     6.644015e+04     1442.823474
# std      2.119003e+05     4479.376494
# min      1.000000e+00    -2461.000000
# 25%      1.055000e+03       19.000000
# 50%      9.147500e+03      169.500000
# 75%      4.308925e+04      789.250000
# max      2.510323e+06    54771.000000

# %%
country_code = set(data['CountryCode'])
print("Total number of countries :",len(country_code))
print("Filtered out countries because of negative new confirmers: ")
for country in pre_country_code:
    if country not in country_code :
        print(country)
# Out:
# Total number of countries : 40
# Filtered out countries because of negative new confirmers:

# %%
country_code
# Out:
# {'AFG',
#  'AUS',
#  'BEL',
#  'BRA',
#  'CAN',
#  'CHE',
#  'CHL',
#  'CHN',
#  'COL',
#  'CZE',
#  'DEU',
#  'DNK',
#  'DOM',
#  'ECU',
#  'ESP',
#  'FIN',
#  'GBR',
#  'IDN',
#  'IRL',
#  'IRN',
#  'ITA',
#  'JPN',
#  'KOR',
#  'LUX',
#  'MEX',
#  'MYS',
#  'NLD',
#  'NOR',
#  'PAK',
#  'PAN',
#  'PHL',
#  'PRT',
#  'RUS',
#  'SAU',
#  'SGP',
#  'SRB',
#  'SWE',
#  'THA',
#  'TUR',
#  'USA'}

# %% [markdown]
# # GEE with a policy variable
# ## Model strucutre
# - y ~ intercept + policy_variable
# - y ~ intercept + days + policy_variable
# - y ~ intercept + days + log(days) + policy_variable

# %%
columns = list(data.columns)
for i ,column in enumerate(columns) : 
    columns[i] = column.replace(' ', '').replace('/','')
data.columns = columns

# %%
columns
# Out:
# ['CountryCode',
#  'Days',
#  'C1_Schoolclosing',
#  'C2_Workplaceclosing',
#  'C3_Cancelpublicevents',
#  'C4_Restrictionsongatherings',
#  'C5_Closepublictransport',
#  'C6_Stayathomerequirements',
#  'C7_Restrictionsoninternalmovement',
#  'C8_Internationaltravelcontrols',
#  'E1_Incomesupport',
#  'E2_Debtcontractrelief',
#  'E3_Fiscalmeasures',
#  'E4_Internationalsupport',
#  'H1_Publicinformationcampaigns',
#  'H2_Testingpolicy',
#  'H3_Contacttracing',
#  'H4_Emergencyinvestmentinhealthcare',
#  'H5_Investmentinvaccines',
#  'ConfirmedCases',
#  'DailyConfirmed']

# %%
# data = data[data['CountryCode']=='USA']
data = data[data['DailyConfirmed'] >= 0]

# %%
variables = data.columns[2:-2]

# %%
variables
# Out:
# Index(['C1_Schoolclosing', 'C2_Workplaceclosing', 'C3_Cancelpublicevents',
#        'C4_Restrictionsongatherings', 'C5_Closepublictransport',
#        'C6_Stayathomerequirements', 'C7_Restrictionsoninternalmovement',
#        'C8_Internationaltravelcontrols', 'E1_Incomesupport',
#        'E2_Debtcontractrelief', 'E3_Fiscalmeasures', 'E4_Internationalsupport',
#        'H1_Publicinformationcampaigns', 'H2_Testingpolicy',
#        'H3_Contacttracing', 'H4_Emergencyinvestmentinhealthcare',
#        'H5_Investmentinvaccines'],
#       dtype='object')

# %%
fam = sm.families.Poisson()
ind = sm.cov_struct.Independence()

variable_dict = {}

for variable in variables:
    sub_data = data.loc[:,['DailyConfirmed', 'Days', 'CountryCode', variable]]
    sub_data = sub_data.fillna(0)
    print("Removing rows by NA value")
    print("No. of removed rows:", len(data['Days'])-len(sub_data['Days']))
    try : 
        mod = smf.gee("DailyConfirmed ~  "+variable , "CountryCode", sub_data , cov_struct = ind, family = fam)
        res = mod.fit()
        country_code = set(sub_data['CountryCode'])

        pval = res.pvalues[1]
        coef = res.params[1]
        variable_dict[variable] = {'coef':coef, 'pval':pval}
        print(res.summary())
        for country in country_code :
            predict_country = sub_data[sub_data['CountryCode']==country]
            predicted = res.predict(predict_country)
            plt.plot(predict_country['Days'], predicted, '-')
            plt.plot(predict_country['Days'], predict_country['DailyConfirmed'], '-')
        plt.show()
    except:
        print("Failed to fit the model using", variable)
# Out:
# Removing rows by NA value
# No. of removed rows: 0
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:              DailyConfirmed   No. Observations:                 5300
# Model:                                 GEE   No. clusters:                       40
# Method:                        Generalized   Min. cluster size:                 105
#                       Estimating Equations   Max. cluster size:                 180
# Family:                            Poisson   Mean cluster size:               132.5
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Fri, 03 Jul 2020   Scale:                           1.000
# Covariance type:                    robust   Time:                         02:25:34
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            6.9034      0.489     14.121      0.000       5.945       7.862
# C1_Schoolclosing     0.5285      0.270      1.958      0.050      -0.001       1.058
# ==============================================================================
# Skew:                          5.7599   Kurtosis:                      38.1405
# Centered skew:                 2.1703   Centered kurtosis:             33.9296
# ==============================================================================
# Removing rows by NA value
# No. of removed rows: 0
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:              DailyConfirmed   No. Observations:                 5300
# Model:                                 GEE   No. clusters:                       40
# Method:                        Generalized   Min. cluster size:                 105
#                       Estimating Equations   Max. cluster size:                 180
# Family:                            Poisson   Mean cluster size:               132.5
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Fri, 03 Jul 2020   Scale:                           1.000
# Covariance type:                    robust   Time:                         02:25:35
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept               6.8775      0.399     17.232      0.000       6.095       7.660
# C2_Workplaceclosing     0.6686      0.322      2.076      0.038       0.037       1.300
# ==============================================================================
# Skew:                          5.7492   Kurtosis:                      38.1217
# Centered skew:                 2.2222   Centered kurtosis:             34.1569
# ==============================================================================
# Removing rows by NA value
# No. of removed rows: 0
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:              DailyConfirmed   No. Observations:                 5300
# Model:                                 GEE   No. clusters:                       40
# Method:                        Generalized   Min. cluster size:                 105
#                       Estimating Equations   Max. cluster size:                 180
# Family:                            Poisson   Mean cluster size:               132.5
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Fri, 03 Jul 2020   Scale:                           1.000
# Covariance type:                    robust   Time:                         02:25:35
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 7.2346      0.511     14.169      0.000       6.234       8.235
# C3_Cancelpublicevents     0.0599      0.306      0.195      0.845      -0.540       0.660
# ==============================================================================
# Skew:                          5.7182   Kurtosis:                      37.6106
# Centered skew:                 2.0686   Centered kurtosis:             32.9502
# ==============================================================================
# Removing rows by NA value
# No. of removed rows: 0
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:              DailyConfirmed   No. Observations:                 5300
# Model:                                 GEE   No. clusters:                       40
# Method:                        Generalized   Min. cluster size:                 105
#                       Estimating Equations   Max. cluster size:                 180
# Family:                            Poisson   Mean cluster size:               132.5
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Fri, 03 Jul 2020   Scale:                           1.000
# Covariance type:                    robust   Time:                         02:25:35
# ===============================================================================================
#                                   coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       6.7410      0.340     19.811      0.000       6.074       7.408
# C4_Restrictionsongatherings     0.8447      0.276      3.060      0.002       0.304       1.386
# ==============================================================================
# Skew:                          5.7333   Kurtosis:                      38.1041
# Centered skew:                 2.2669   Centered kurtosis:             34.6559
# ==============================================================================
# Removing rows by NA value
# No. of removed rows: 0
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:              DailyConfirmed   No. Observations:                 5300
# Model:                                 GEE   No. clusters:                       40
# Method:                        Generalized   Min. cluster size:                 105
#                       Estimating Equations   Max. cluster size:                 180
# Family:                            Poisson   Mean cluster size:               132.5
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Fri, 03 Jul 2020   Scale:                           1.000
# Covariance type:                    robust   Time:                         02:25:36
# ===========================================================================================
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   7.0494      0.403     17.486      0.000       6.259       7.840
# C5_Closepublictransport     0.6547      0.319      2.055      0.040       0.030       1.279
# ==============================================================================
# Skew:                          5.7254   Kurtosis:                      37.7986
# Centered skew:                 2.1441   Centered kurtosis:             33.6254
# ==============================================================================
# Removing rows by NA value
# No. of removed rows: 0
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:              DailyConfirmed   No. Observations:                 5300
# Model:                                 GEE   No. clusters:                       40
# Method:                        Generalized   Min. cluster size:                 105
#                       Estimating Equations   Max. cluster size:                 180
# Family:                            Poisson   Mean cluster size:               132.5
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Fri, 03 Jul 2020   Scale:                           1.000
# Covariance type:                    robust   Time:                         02:25:36
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                     6.8273      0.446     15.306      0.000       5.953       7.702
# C6_Stayathomerequirements     0.9996      0.326      3.063      0.002       0.360       1.639
# ==============================================================================
# Skew:                          5.7684   Kurtosis:                      38.3516
# Centered skew:                 2.2049   Centered kurtosis:             34.2607
# ==============================================================================
# Removing rows by NA value
# No. of removed rows: 0
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:              DailyConfirmed   No. Observations:                 5300
# Model:                                 GEE   No. clusters:                       40
# Method:                        Generalized   Min. cluster size:                 105
#                       Estimating Equations   Max. cluster size:                 180
# Family:                            Poisson   Mean cluster size:               132.5
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Fri, 03 Jul 2020   Scale:                           1.000
# Covariance type:                    robust   Time:                         02:25:37
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                             6.8577      0.396     17.310      0.000       6.081       7.634
# C7_Restrictionsoninternalmovement     0.7342      0.234      3.136      0.002       0.275       1.193
# ==============================================================================
# Skew:                          5.7456   Kurtosis:                      38.0786
# Centered skew:                 2.1974   Centered kurtosis:             33.9132
# ==============================================================================
# Removing rows by NA value
# No. of removed rows: 0
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:              DailyConfirmed   No. Observations:                 5300
# Model:                                 GEE   No. clusters:                       40
# Method:                        Generalized   Min. cluster size:                 105
#                       Estimating Equations   Max. cluster size:                 180
# Family:                            Poisson   Mean cluster size:               132.5
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Fri, 03 Jul 2020   Scale:                           1.000
# Covariance type:                    robust   Time:                         02:25:37
# ==================================================================================================
#                                      coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                          6.6065      0.282     23.411      0.000       6.053       7.160
# C8_Internationaltravelcontrols     0.8971      0.424      2.116      0.034       0.066       1.728
# ==============================================================================
# Skew:                          5.7063   Kurtosis:                      37.9159
# Centered skew:                 2.2582   Centered kurtosis:             34.4161
# ==============================================================================
# Removing rows by NA value
# No. of removed rows: 0
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:              DailyConfirmed   No. Observations:                 5300
# Model:                                 GEE   No. clusters:                       40
# Method:                        Generalized   Min. cluster size:                 105
#                       Estimating Equations   Max. cluster size:                 180
# Family:                            Poisson   Mean cluster size:               132.5
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Fri, 03 Jul 2020   Scale:                           1.000
# Covariance type:                    robust   Time:                         02:25:37
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            6.8670      0.310     22.182      0.000       6.260       7.474
# E1_Incomesupport     0.8909      0.448      1.987      0.047       0.012       1.770
# ==============================================================================
# Skew:                          5.6489   Kurtosis:                      37.1405
# Centered skew:                 2.2086   Centered kurtosis:             34.0491
# ==============================================================================
# Removing rows by NA value
# No. of removed rows: 0
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:              DailyConfirmed   No. Observations:                 5300
# Model:                                 GEE   No. clusters:                       40
# Method:                        Generalized   Min. cluster size:                 105
#                       Estimating Equations   Max. cluster size:                 180
# Family:                            Poisson   Mean cluster size:               132.5
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Fri, 03 Jul 2020   Scale:                           1.000
# Covariance type:                    robust   Time:                         02:25:38
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 7.0893      0.423     16.754      0.000       6.260       7.919
# E2_Debtcontractrelief     0.3830      0.260      1.475      0.140      -0.126       0.892
# ==============================================================================
# Skew:                          5.7405   Kurtosis:                      37.9215
# Centered skew:                 2.1358   Centered kurtosis:             33.7929
# ==============================================================================
# Removing rows by NA value
# No. of removed rows: 0
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:              DailyConfirmed   No. Observations:                 5300
# Model:                                 GEE   No. clusters:                       40
# Method:                        Generalized   Min. cluster size:                 105
#                       Estimating Equations   Max. cluster size:                 180
# Family:                            Poisson   Mean cluster size:               132.5
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Fri, 03 Jul 2020   Scale:                           1.000
# Covariance type:                    robust   Time:                         02:25:38
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             7.2774      0.358     20.349      0.000       6.577       7.978
# E3_Fiscalmeasures    -0.0027      0.029     -0.092      0.926      -0.060       0.055
# ==============================================================================
# Skew:                          5.7105   Kurtosis:                      37.5232
# Centered skew:                 2.0529   Centered kurtosis:             32.7838
# ==============================================================================
# Removing rows by NA value
# No. of removed rows: 0
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:              DailyConfirmed   No. Observations:                 5300
# Model:                                 GEE   No. clusters:                       40
# Method:                        Generalized   Min. cluster size:                 105
#                       Estimating Equations   Max. cluster size:                 180
# Family:                            Poisson   Mean cluster size:               132.5
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Fri, 03 Jul 2020   Scale:                           1.000
# Covariance type:                    robust   Time:                         02:25:39
# ===========================================================================================
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   7.2701      0.350     20.743      0.000       6.583       7.957
# E4_Internationalsupport     0.0897      0.062      1.455      0.146      -0.031       0.211
# ==============================================================================
# Skew:                          5.7002   Kurtosis:                      37.4310
# Centered skew:                 2.0404   Centered kurtosis:             32.6563
# ==============================================================================
# Removing rows by NA value
# No. of removed rows: 0
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:              DailyConfirmed   No. Observations:                 5300
# Model:                                 GEE   No. clusters:                       40
# Method:                        Generalized   Min. cluster size:                 105
#                       Estimating Equations   Max. cluster size:                 180
# Family:                            Poisson   Mean cluster size:               132.5
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Fri, 03 Jul 2020   Scale:                           1.000
# Covariance type:                    robust   Time:                         02:25:39
# =================================================================================================
#                                     coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# Intercept                         7.1717      0.344     20.859      0.000       6.498       7.846
# H1_Publicinformationcampaigns     0.1192      0.370      0.322      0.748      -0.607       0.845
# ==============================================================================
# Skew:                          5.7158   Kurtosis:                      37.6189
# Centered skew:                 2.0930   Centered kurtosis:             33.0855
# ==============================================================================
# Removing rows by NA value
# No. of removed rows: 0
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:              DailyConfirmed   No. Observations:                 5300
# Model:                                 GEE   No. clusters:                       40
# Method:                        Generalized   Min. cluster size:                 105
#                       Estimating Equations   Max. cluster size:                 180
# Family:                            Poisson   Mean cluster size:               132.5
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Fri, 03 Jul 2020   Scale:                           1.000
# Covariance type:                    robust   Time:                         02:25:39
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            6.3171      0.580     10.895      0.000       5.181       7.453
# H2_Testingpolicy     1.6352      1.090      1.499      0.134      -0.502       3.772
# ==============================================================================
# Skew:                          5.5948   Kurtosis:                      37.7138
# Centered skew:                 2.3738   Centered kurtosis:             34.2738
# ==============================================================================
# Removing rows by NA value
# No. of removed rows: 0
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:              DailyConfirmed   No. Observations:                 5300
# Model:                                 GEE   No. clusters:                       40
# Method:                        Generalized   Min. cluster size:                 105
#                       Estimating Equations   Max. cluster size:                 180
# Family:                            Poisson   Mean cluster size:               132.5
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Fri, 03 Jul 2020   Scale:                           1.000
# Covariance type:                    robust   Time:                         02:25:40
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             7.9872      0.449     17.785      0.000       7.107       8.867
# H3_Contacttracing    -1.3172      0.552     -2.386      0.017      -2.400      -0.235
# ==============================================================================
# Skew:                          5.5549   Kurtosis:                      36.0675
# Centered skew:                 1.9171   Centered kurtosis:             30.6661
# ==============================================================================
# Removing rows by NA value
# No. of removed rows: 0
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:              DailyConfirmed   No. Observations:                 5300
# Model:                                 GEE   No. clusters:                       40
# Method:                        Generalized   Min. cluster size:                 105
#                       Estimating Equations   Max. cluster size:                 180
# Family:                            Poisson   Mean cluster size:               132.5
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Fri, 03 Jul 2020   Scale:                           1.000
# Covariance type:                    robust   Time:                         02:25:40
# ======================================================================================================
#                                          coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                              7.2755      0.355     20.479      0.000       6.579       7.972
# H4_Emergencyinvestmentinhealthcare     0.0065      0.025      0.256      0.798      -0.043       0.056
# ==============================================================================
# Skew:                          5.7111   Kurtosis:                      37.5314
# Centered skew:                 2.0537   Centered kurtosis:             32.7821
# ==============================================================================
# Removing rows by NA value
# No. of removed rows: 0
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:              DailyConfirmed   No. Observations:                 5300
# Model:                                 GEE   No. clusters:                       40
# Method:                        Generalized   Min. cluster size:                 105
#                       Estimating Equations   Max. cluster size:                 180
# Family:                            Poisson   Mean cluster size:               132.5
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Fri, 03 Jul 2020   Scale:                           1.000
# Covariance type:                    robust   Time:                         02:25:40
# ===========================================================================================
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   7.2775      0.354     20.554      0.000       6.584       7.971
# H5_Investmentinvaccines    -0.0164      0.048     -0.343      0.732      -0.110       0.077
# ==============================================================================
# Skew:                          5.7107   Kurtosis:                      37.5256
# Centered skew:                 2.0534   Centered kurtosis:             32.7892
# ==============================================================================

# %%
variable_dicts
# Out:
# [{'C1_Schoolclosing': {'coef': 0.01619293571995623,
#    'pval': 3.586151946930524e-05},
#   'C2_Workplaceclosing': {'coef': 0.016410338734480275,
#    'pval': 0.00016918252466420995},
#   'C3_Cancelpublicevents': {'coef': 0.015297516774498967,
#    'pval': 1.3299182156496417e-05},
#   'C4_Restrictionsongatherings': {'coef': 0.015637465011084695,
#    'pval': 0.00018643823465740032},
#   'C5_Closepublictransport': {'coef': 0.0168826631188315,
#    'pval': 1.827655613726382e-05},
#   'C6_Stayathomerequirements': {'coef': 0.01701288375184113,
#    'pval': 6.74368754742928e-05},
#   'C7_Restrictionsoninternalmovement': {'coef': 0.016691356483662587,
#    'pval': 7.499095405000919e-05},
#   'C8_Internationaltravelcontrols': {'coef': 0.015137320551093509,
#    'pval': 0.00011980218059637357},
#   'E1_Incomesupport': {'coef': 0.014428808616400385,
#    'pval': 0.00017709001114955383},
#   'E2_Debtcontractrelief': {'coef': 0.015259919938786125,
#    'pval': 0.00013385189970088307},
#   'E3_Fiscalmeasures': {'coef': 0.01523826001714777,
#    'pval': 3.2894932634466265e-05},
#   'E4_Internationalsupport': {'coef': 0.015209429579068217,
#    'pval': 3.613400125800749e-05},
#   'H1_Publicinformationcampaigns': {'coef': 0.01545330109504082,
#    'pval': 9.357726643805219e-05},
#   'H2_Testingpolicy': {'coef': 0.013560749882093425,
#    'pval': 7.2938856818224374e-06},
#   'H3_Contacttracing': {'coef': 0.014275527854664162,
#    'pval': 4.3639108403618784e-05},
#   'H4_Emergencyinvestmentinhealthcare': {'coef': 0.015305599737375098,
#    'pval': 3.615317111453384e-05},
#   'H5_Investmentinvaccines': {'coef': 0.015215662645194028,
#    'pval': 3.422681927071344e-05}},
#  {},
#  {}]

# %%
simple_marker_result = pd.DataFrame.from_dict(variable_dict).transpose().sort_values(by=['pval'])
simple_marker_result.to_csv('simple_marker_GEE_result.csv',)
simple_marker_result
# Out:
#                                         coef      pval
# C7_Restrictionsoninternalmovement   0.734231  0.001714
# C6_Stayathomerequirements           0.999596  0.002192
# C4_Restrictionsongatherings         0.844710  0.002215
# H3_Contacttracing                  -1.317245  0.017056
# C8_Internationaltravelcontrols      0.897051  0.034356
# C2_Workplaceclosing                 0.668575  0.037881
# C5_Closepublictransport             0.654747  0.039889
# E1_Incomesupport                    0.890892  0.046901
# C1_Schoolclosing                    0.528542  0.050254
# H2_Testingpolicy                    1.635173  0.133745
# E2_Debtcontractrelief               0.383008  0.140287
# E4_Internationalsupport             0.089726  0.145741
# H5_Investmentinvaccines            -0.016382  0.731504
# H1_Publicinformationcampaigns       0.119152  0.747707
# H4_Emergencyinvestmentinhealthcare  0.006499  0.797853
# C3_Cancelpublicevents               0.059862  0.845010
# E3_Fiscalmeasures                  -0.002714  0.926436

# %%
fam = sm.families.Poisson()
ind = sm.cov_struct.Independence()
AR = sm.cov_struct.Autoregressive()
exc = sm.cov_struct.Exchangeable()

working_corr = [ind,AR,exc]

variable_dicts = [{},{},{}]

for variable in variables:
    sub_data = data.loc[:,['DailyConfirmed', 'Days', 'CountryCode', variable]]
    sub_data = sub_data.fillna(0)
    print("Removing rows by NA value")
    print("No. of removed rows:", len(data['Days'])-len(sub_data['Days']))
    try : 
        for i in range(len(working_corr)) :
            mod = smf.gee("DailyConfirmed ~  Days + "+variable , "CountryCode", sub_data , cov_struct = working_corr[i], family = fam)
            res = mod.fit()
            country_code = set(sub_data['CountryCode'])

            pval = res.pvalues[1]
            coef = res.params[1]
            
            variable_dicts[i][variable] = {'coef':coef, 'pval':pval}
#             print(res.summary())        
#         for country in country_code :
#             predict_country = sub_data[sub_data['CountryCode']==country]
#             predicted = res.predict(predict_country)
#             plt.plot(predict_country['Days'], predicted, '-')
#             plt.plot(predict_country['Days'], predict_country['DailyConfirmed'], '-')
#         plt.show()
    except Exception as e:
        print(e)
        print("Failed to fit the model using", variable)
# Out:
# Removing rows by NA value
# No. of removed rows: 0
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:              DailyConfirmed   No. Observations:                 5300
# Model:                                 GEE   No. clusters:                       40
# Method:                        Generalized   Min. cluster size:                 105
#                       Estimating Equations   Max. cluster size:                 180
# Family:                            Poisson   Mean cluster size:               132.5
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Fri, 03 Jul 2020   Scale:                           1.000
# Covariance type:                    robust   Time:                         02:32:09
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            5.4646      0.374     14.620      0.000       4.732       6.197
# Days                 0.0162      0.004      4.133      0.000       0.009       0.024
# C1_Schoolclosing     0.6274      0.282      2.225      0.026       0.075       1.180
# ==============================================================================
# Skew:                          5.4334   Kurtosis:                      35.9445
# Centered skew:                 2.2158   Centered kurtosis:             31.6057
# ==============================================================================
# Autoregressive: unable to find right bracket
# Failed to fit the model using C1_Schoolclosing
# Removing rows by NA value
# No. of removed rows: 0
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:              DailyConfirmed   No. Observations:                 5300
# Model:                                 GEE   No. clusters:                       40
# Method:                        Generalized   Min. cluster size:                 105
#                       Estimating Equations   Max. cluster size:                 180
# Family:                            Poisson   Mean cluster size:               132.5
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Fri, 03 Jul 2020   Scale:                           1.000
# Covariance type:                    robust   Time:                         02:32:11
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept               5.4016      0.434     12.444      0.000       4.551       6.252
# Days                    0.0164      0.004      3.761      0.000       0.008       0.025
# C2_Workplaceclosing     0.8100      0.409      1.981      0.048       0.008       1.612
# ==============================================================================
# Skew:                          5.4189   Kurtosis:                      35.9555
# Centered skew:                 2.2729   Centered kurtosis:             31.8247
# ==============================================================================
# Autoregressive: unable to find right bracket
# Failed to fit the model using C2_Workplaceclosing
# Removing rows by NA value
# No. of removed rows: 0
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:              DailyConfirmed   No. Observations:                 5300
# Model:                                 GEE   No. clusters:                       40
# Method:                        Generalized   Min. cluster size:                 105
#                       Estimating Equations   Max. cluster size:                 180
# Family:                            Poisson   Mean cluster size:               132.5
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Fri, 03 Jul 2020   Scale:                           1.000
# Covariance type:                    robust   Time:                         02:32:13
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 5.9544      0.348     17.132      0.000       5.273       6.636
# Days                      0.0153      0.004      4.355      0.000       0.008       0.022
# C3_Cancelpublicevents     0.0571      0.293      0.194      0.846      -0.518       0.632
# ==============================================================================
# Skew:                          5.3740   Kurtosis:                      35.1029
# Centered skew:                 2.0925   Centered kurtosis:             30.4853
# ==============================================================================
# Autoregressive: unable to find right bracket
# Failed to fit the model using C3_Cancelpublicevents
# Removing rows by NA value
# No. of removed rows: 0
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:              DailyConfirmed   No. Observations:                 5300
# Model:                                 GEE   No. clusters:                       40
# Method:                        Generalized   Min. cluster size:                 105
#                       Estimating Equations   Max. cluster size:                 180
# Family:                            Poisson   Mean cluster size:               132.5
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Fri, 03 Jul 2020   Scale:                           1.000
# Covariance type:                    robust   Time:                         02:32:14
# ===============================================================================================
#                                   coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                       5.4798      0.361     15.162      0.000       4.771       6.188
# Days                            0.0156      0.004      3.737      0.000       0.007       0.024
# C4_Restrictionsongatherings     0.7470      0.309      2.418      0.016       0.142       1.352
# ==============================================================================
# Skew:                          5.4182   Kurtosis:                      35.9998
# Centered skew:                 2.2672   Centered kurtosis:             31.9660
# ==============================================================================
# Autoregressive: unable to find right bracket
# Failed to fit the model using C4_Restrictionsongatherings
# Removing rows by NA value
# No. of removed rows: 0
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:              DailyConfirmed   No. Observations:                 5300
# Model:                                 GEE   No. clusters:                       40
# Method:                        Generalized   Min. cluster size:                 105
#                       Estimating Equations   Max. cluster size:                 180
# Family:                            Poisson   Mean cluster size:               132.5
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Fri, 03 Jul 2020   Scale:                           1.000
# Covariance type:                    robust   Time:                         02:32:15
# ===========================================================================================
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   5.5387      0.262     21.107      0.000       5.024       6.053
# Days                        0.0169      0.004      4.285      0.000       0.009       0.025
# C5_Closepublictransport     0.8977      0.327      2.746      0.006       0.257       1.538
# ==============================================================================
# Skew:                          5.3447   Kurtosis:                      35.1912
# Centered skew:                 2.1445   Centered kurtosis:             30.6912
# ==============================================================================
# Autoregressive: unable to find right bracket
# Failed to fit the model using C5_Closepublictransport
# Removing rows by NA value
# No. of removed rows: 0
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:              DailyConfirmed   No. Observations:                 5300
# Model:                                 GEE   No. clusters:                       40
# Method:                        Generalized   Min. cluster size:                 105
#                       Estimating Equations   Max. cluster size:                 180
# Family:                            Poisson   Mean cluster size:               132.5
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Fri, 03 Jul 2020   Scale:                           1.000
# Covariance type:                    robust   Time:                         02:32:16
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                     5.2829      0.394     13.406      0.000       4.511       6.055
# Days                          0.0170      0.004      3.985      0.000       0.009       0.025
# C6_Stayathomerequirements     1.2186      0.371      3.287      0.001       0.492       1.945
# ==============================================================================
# Skew:                          5.4014   Kurtosis:                      36.0554
# Centered skew:                 2.2313   Centered kurtosis:             31.6745
# ==============================================================================
# Autoregressive: unable to find right bracket
# Failed to fit the model using C6_Stayathomerequirements
# Removing rows by NA value
# No. of removed rows: 0
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:              DailyConfirmed   No. Observations:                 5300
# Model:                                 GEE   No. clusters:                       40
# Method:                        Generalized   Min. cluster size:                 105
#                       Estimating Equations   Max. cluster size:                 180
# Family:                            Poisson   Mean cluster size:               132.5
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Fri, 03 Jul 2020   Scale:                           1.000
# Covariance type:                    robust   Time:                         02:32:18
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                             5.3716      0.312     17.201      0.000       4.760       5.984
# Days                                  0.0167      0.004      3.960      0.000       0.008       0.025
# C7_Restrictionsoninternalmovement     0.8563      0.262      3.267      0.001       0.343       1.370
# ==============================================================================
# Skew:                          5.3975   Kurtosis:                      35.7931
# Centered skew:                 2.2442   Centered kurtosis:             31.5663
# ==============================================================================
# Autoregressive: unable to find right bracket
# Failed to fit the model using C7_Restrictionsoninternalmovement
# Removing rows by NA value
# No. of removed rows: 0
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:              DailyConfirmed   No. Observations:                 5300
# Model:                                 GEE   No. clusters:                       40
# Method:                        Generalized   Min. cluster size:                 105
#                       Estimating Equations   Max. cluster size:                 180
# Family:                            Poisson   Mean cluster size:               132.5
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Fri, 03 Jul 2020   Scale:                           1.000
# Covariance type:                    robust   Time:                         02:32:19
# ==================================================================================================
#                                      coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                          5.5156      0.375     14.697      0.000       4.780       6.251
# Days                               0.0151      0.004      3.847      0.000       0.007       0.023
# C8_Internationaltravelcontrols     0.6498      0.379      1.716      0.086      -0.092       1.392
# ==============================================================================
# Skew:                          5.3656   Kurtosis:                      35.5355
# Centered skew:                 2.2450   Centered kurtosis:             31.5579
# ==============================================================================
# Autoregressive: unable to find right bracket
# Failed to fit the model using C8_Internationaltravelcontrols
# Removing rows by NA value
# No. of removed rows: 0
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:              DailyConfirmed   No. Observations:                 5300
# Model:                                 GEE   No. clusters:                       40
# Method:                        Generalized   Min. cluster size:                 105
#                       Estimating Equations   Max. cluster size:                 180
# Family:                            Poisson   Mean cluster size:               132.5
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Fri, 03 Jul 2020   Scale:                           1.000
# Covariance type:                    robust   Time:                         02:32:20
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            5.8861      0.207     28.475      0.000       5.481       6.291
# Days                 0.0144      0.004      3.750      0.000       0.007       0.022
# E1_Incomesupport     0.3866      0.447      0.864      0.387      -0.490       1.263
# ==============================================================================
# Skew:                          5.3475   Kurtosis:                      34.9037
# Centered skew:                 2.1245   Centered kurtosis:             30.5991
# ==============================================================================
# Autoregressive: unable to find right bracket
# Failed to fit the model using E1_Incomesupport
# Removing rows by NA value
# No. of removed rows: 0
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:              DailyConfirmed   No. Observations:                 5300
# Model:                                 GEE   No. clusters:                       40
# Method:                        Generalized   Min. cluster size:                 105
#                       Estimating Equations   Max. cluster size:                 180
# Family:                            Poisson   Mean cluster size:               132.5
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Fri, 03 Jul 2020   Scale:                           1.000
# Covariance type:                    robust   Time:                         02:32:21
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                 6.0098      0.243     24.744      0.000       5.534       6.486
# Days                      0.0153      0.004      3.819      0.000       0.007       0.023
# E2_Debtcontractrelief    -0.0222      0.315     -0.070      0.944      -0.640       0.596
# ==============================================================================
# Skew:                          5.3599   Kurtosis:                      34.9511
# Centered skew:                 2.0726   Centered kurtosis:             30.2609
# ==============================================================================
# Autoregressive: unable to find right bracket
# Failed to fit the model using E2_Debtcontractrelief
# Removing rows by NA value
# No. of removed rows: 0
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:              DailyConfirmed   No. Observations:                 5300
# Model:                                 GEE   No. clusters:                       40
# Method:                        Generalized   Min. cluster size:                 105
#                       Estimating Equations   Max. cluster size:                 180
# Family:                            Poisson   Mean cluster size:               132.5
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Fri, 03 Jul 2020   Scale:                           1.000
# Covariance type:                    robust   Time:                         02:32:22
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             5.9968      0.216     27.773      0.000       5.574       6.420
# Days                  0.0152      0.004      4.152      0.000       0.008       0.022
# E3_Fiscalmeasures     0.0126      0.026      0.488      0.625      -0.038       0.063
# ==============================================================================
# Skew:                          5.3649   Kurtosis:                      35.0083
# Centered skew:                 2.0782   Centered kurtosis:             30.3353
# ==============================================================================
# Autoregressive: unable to find right bracket
# Failed to fit the model using E3_Fiscalmeasures
# Removing rows by NA value
# No. of removed rows: 0
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:              DailyConfirmed   No. Observations:                 5300
# Model:                                 GEE   No. clusters:                       40
# Method:                        Generalized   Min. cluster size:                 105
#                       Estimating Equations   Max. cluster size:                 180
# Family:                            Poisson   Mean cluster size:               132.5
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Fri, 03 Jul 2020   Scale:                           1.000
# Covariance type:                    robust   Time:                         02:32:24
# ===========================================================================================
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   5.9972      0.213     28.104      0.000       5.579       6.415
# Days                        0.0152      0.004      4.131      0.000       0.008       0.022
# E4_Internationalsupport     0.0771      0.070      1.094      0.274      -0.061       0.215
# ==============================================================================
# Skew:                          5.3517   Kurtosis:                      34.8788
# Centered skew:                 2.0671   Centered kurtosis:             30.2098
# ==============================================================================
# Autoregressive: unable to find right bracket
# Failed to fit the model using E4_Internationalsupport
# Removing rows by NA value
# No. of removed rows: 0
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:              DailyConfirmed   No. Observations:                 5300
# Model:                                 GEE   No. clusters:                       40
# Method:                        Generalized   Min. cluster size:                 105
#                       Estimating Equations   Max. cluster size:                 180
# Family:                            Poisson   Mean cluster size:               132.5
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Fri, 03 Jul 2020   Scale:                           1.000
# Covariance type:                    robust   Time:                         02:32:25
# =================================================================================================
#                                     coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# Intercept                         5.7885      0.427     13.563      0.000       4.952       6.625
# Days                              0.0155      0.004      3.907      0.000       0.008       0.023
# H1_Publicinformationcampaigns     0.2181      0.331      0.659      0.510      -0.431       0.867
# ==============================================================================
# Skew:                          5.3737   Kurtosis:                      35.2454
# Centered skew:                 2.1467   Centered kurtosis:             30.8841
# ==============================================================================
# Autoregressive: unable to find right bracket
# Failed to fit the model using H1_Publicinformationcampaigns
# Removing rows by NA value
# No. of removed rows: 0
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:              DailyConfirmed   No. Observations:                 5300
# Model:                                 GEE   No. clusters:                       40
# Method:                        Generalized   Min. cluster size:                 105
#                       Estimating Equations   Max. cluster size:                 180
# Family:                            Poisson   Mean cluster size:               132.5
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Fri, 03 Jul 2020   Scale:                           1.000
# Covariance type:                    robust   Time:                         02:32:26
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            5.5131      0.559      9.854      0.000       4.417       6.610
# Days                 0.0136      0.003      4.485      0.000       0.008       0.019
# H2_Testingpolicy     1.0656      0.950      1.122      0.262      -0.797       2.928
# ==============================================================================
# Skew:                          5.3352   Kurtosis:                      35.9442
# Centered skew:                 2.3369   Centered kurtosis:             31.8241
# ==============================================================================
# Autoregressive: unable to find right bracket
# Failed to fit the model using H2_Testingpolicy
# Removing rows by NA value
# No. of removed rows: 0
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:              DailyConfirmed   No. Observations:                 5300
# Model:                                 GEE   No. clusters:                       40
# Method:                        Generalized   Min. cluster size:                 105
#                       Estimating Equations   Max. cluster size:                 180
# Family:                            Poisson   Mean cluster size:               132.5
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Fri, 03 Jul 2020   Scale:                           1.000
# Covariance type:                    robust   Time:                         02:32:28
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             6.7447      0.401     16.807      0.000       5.958       7.531
# Days                  0.0143      0.003      4.087      0.000       0.007       0.021
# H3_Contacttracing    -1.2199      0.560     -2.180      0.029      -2.317      -0.123
# ==============================================================================
# Skew:                          5.0728   Kurtosis:                      32.5002
# Centered skew:                 1.6868   Centered kurtosis:             26.1604
# ==============================================================================
# Autoregressive: unable to find right bracket
# Failed to fit the model using H3_Contacttracing
# Removing rows by NA value
# No. of removed rows: 0
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:              DailyConfirmed   No. Observations:                 5300
# Model:                                 GEE   No. clusters:                       40
# Method:                        Generalized   Min. cluster size:                 105
#                       Estimating Equations   Max. cluster size:                 180
# Family:                            Poisson   Mean cluster size:               132.5
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Fri, 03 Jul 2020   Scale:                           1.000
# Covariance type:                    robust   Time:                         02:32:29
# ======================================================================================================
#                                          coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                              5.9873      0.215     27.842      0.000       5.566       6.409
# Days                                   0.0153      0.004      4.131      0.000       0.008       0.023
# H4_Emergencyinvestmentinhealthcare     0.0442      0.024      1.871      0.061      -0.002       0.091
# ==============================================================================
# Skew:                          5.3639   Kurtosis:                      35.0102
# Centered skew:                 2.0788   Centered kurtosis:             30.3075
# ==============================================================================
# Autoregressive: unable to find right bracket
# Failed to fit the model using H4_Emergencyinvestmentinhealthcare
# Removing rows by NA value
# No. of removed rows: 0
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:              DailyConfirmed   No. Observations:                 5300
# Model:                                 GEE   No. clusters:                       40
# Method:                        Generalized   Min. cluster size:                 105
#                       Estimating Equations   Max. cluster size:                 180
# Family:                            Poisson   Mean cluster size:               132.5
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Fri, 03 Jul 2020   Scale:                           1.000
# Covariance type:                    robust   Time:                         02:32:30
# ===========================================================================================
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                   6.0025      0.213     28.231      0.000       5.586       6.419
# Days                        0.0152      0.004      4.143      0.000       0.008       0.022
# H5_Investmentinvaccines    -0.0011      0.044     -0.024      0.980      -0.088       0.085
# ==============================================================================
# Skew:                          5.3637   Kurtosis:                      34.9917
# Centered skew:                 2.0769   Centered kurtosis:             30.3183
# ==============================================================================
# Autoregressive: unable to find right bracket
# Failed to fit the model using H5_Investmentinvaccines

# %%
variable_dicts
# Out:
# [{'C1_Schoolclosing': {'coef': 0.01619293571995623,
#    'pval': 3.586151946930524e-05},
#   'C2_Workplaceclosing': {'coef': 0.016410338734480275,
#    'pval': 0.00016918252466420995},
#   'C3_Cancelpublicevents': {'coef': 0.015297516774498967,
#    'pval': 1.3299182156496417e-05},
#   'C4_Restrictionsongatherings': {'coef': 0.015637465011084695,
#    'pval': 0.00018643823465740032},
#   'C5_Closepublictransport': {'coef': 0.0168826631188315,
#    'pval': 1.827655613726382e-05},
#   'C6_Stayathomerequirements': {'coef': 0.01701288375184113,
#    'pval': 6.74368754742928e-05},
#   'C7_Restrictionsoninternalmovement': {'coef': 0.016691356483662587,
#    'pval': 7.499095405000919e-05},
#   'C8_Internationaltravelcontrols': {'coef': 0.015137320551093509,
#    'pval': 0.00011980218059637357},
#   'E1_Incomesupport': {'coef': 0.014428808616400385,
#    'pval': 0.00017709001114955383},
#   'E2_Debtcontractrelief': {'coef': 0.015259919938786125,
#    'pval': 0.00013385189970088307},
#   'E3_Fiscalmeasures': {'coef': 0.01523826001714777,
#    'pval': 3.2894932634466265e-05},
#   'E4_Internationalsupport': {'coef': 0.015209429579068217,
#    'pval': 3.613400125800749e-05},
#   'H1_Publicinformationcampaigns': {'coef': 0.01545330109504082,
#    'pval': 9.357726643805219e-05},
#   'H2_Testingpolicy': {'coef': 0.013560749882093425,
#    'pval': 7.2938856818224374e-06},
#   'H3_Contacttracing': {'coef': 0.014275527854664162,
#    'pval': 4.3639108403618784e-05},
#   'H4_Emergencyinvestmentinhealthcare': {'coef': 0.015305599737375098,
#    'pval': 3.615317111453384e-05},
#   'H5_Investmentinvaccines': {'coef': 0.015215662645194028,
#    'pval': 3.422681927071344e-05}},
#  {},
#  {}]

# %%
simple_marker_result = pd.DataFrame.from_dict(variable_dict).transpose().sort_values(by=['pval'])
simple_marker_result.to_csv('simple_marker_with_days_GEE_result.csv',)
simple_marker_result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-76-b41051eecf6a> in <module>
# ----> 1 simple_marker_result = pd.DataFrame.from_dict(variable_dict).transpose().sort_values(by=['pval'])
#       2 simple_marker_result.to_csv('simple_marker_with_days_GEE_result.csv',)
#       3 simple_marker_result
#
# NameError: name 'variable_dict' is not defined

# %%
fam = sm.families.Poisson()
ind = sm.cov_struct.Independence()

variable_dict = {}

for variable in variables:
    sub_data = data.loc[:,['DailyConfirmed', 'Days', 'CountryCode', variable]]
    sub_data = sub_data.fillna(0)
    sub_data['logDays'] = np.log(sub_data['Days'])
    print("Removing rows by NA value")
    print("No. of removed rows:", len(data['Days'])-len(sub_data['Days']))
    try:
        mod = smf.gee("DailyConfirmed ~  Days + logDays + "+variable , "CountryCode", sub_data , cov_struct = ind, family = fam)
        res = mod.fit()
        country_code = list(set(sub_data['CountryCode']))

        pval = res.pvalues[1]
        coef = res.params[1]
        variable_dict[variable] = {'coef':coef, 'pval':pval}
        print(res.summary())
        for country in country_code[:1] :
            predict_country = sub_data[sub_data['CountryCode']==country]
            predicted = res.predict(predict_country)
            plt.plot(predict_country['Days'], predicted, '-')
            plt.plot(predict_country['Days'], predict_country['DailyConfirmed'], '-')
        plt.show()
    except:
        print("Failed to fit the model using", variable)
# Out:
# Removing rows by NA value
# No. of removed rows: 0
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:              DailyConfirmed   No. Observations:                 5300
# Model:                                 GEE   No. clusters:                       40
# Method:                        Generalized   Min. cluster size:                 105
#                       Estimating Equations   Max. cluster size:                 180
# Family:                            Poisson   Mean cluster size:               132.5
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Thu, 02 Jul 2020   Scale:                           1.000
# Covariance type:                    robust   Time:                         21:38:22
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           -4.0306      3.536     -1.140      0.254     -10.962       2.900
# Days                -0.0230      0.016     -1.480      0.139      -0.053       0.007
# logDays              3.0299      1.147      2.642      0.008       0.782       5.278
# C1_Schoolclosing     0.2049      0.356      0.576      0.565      -0.492       0.902
# ==============================================================================
# Skew:                          5.5548   Kurtosis:                      36.8989
# Centered skew:                 2.2717   Centered kurtosis:             32.9238
# ==============================================================================
# Removing rows by NA value
# No. of removed rows: 0
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:              DailyConfirmed   No. Observations:                 5300
# Model:                                 GEE   No. clusters:                       40
# Method:                        Generalized   Min. cluster size:                 105
#                       Estimating Equations   Max. cluster size:                 180
# Family:                            Poisson   Mean cluster size:               132.5
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Thu, 02 Jul 2020   Scale:                           1.000
# Covariance type:                    robust   Time:                         21:38:23
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept              -3.8259      3.723     -1.028      0.304     -11.124       3.472
# Days                   -0.0218      0.018     -1.199      0.230      -0.057       0.014
# logDays                 2.9492      1.248      2.363      0.018       0.503       5.396
# C2_Workplaceclosing     0.3091      0.581      0.532      0.595      -0.830       1.448
# ==============================================================================
# Skew:                          5.5475   Kurtosis:                      36.9027
# Centered skew:                 2.3023   Centered kurtosis:             33.0451
# ==============================================================================
# Removing rows by NA value
# No. of removed rows: 0
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:              DailyConfirmed   No. Observations:                 5300
# Model:                                 GEE   No. clusters:                       40
# Method:                        Generalized   Min. cluster size:                 105
#                       Estimating Equations   Max. cluster size:                 180
# Family:                            Poisson   Mean cluster size:               132.5
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Thu, 02 Jul 2020   Scale:                           1.000
# Covariance type:                    robust   Time:                         21:38:23
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                -5.7858      4.051     -1.428      0.153     -13.726       2.155
# Days                     -0.0344      0.017     -2.042      0.041      -0.067      -0.001
# logDays                   3.7869      1.295      2.924      0.003       1.249       6.325
# C3_Cancelpublicevents    -0.5484      0.359     -1.526      0.127      -1.253       0.156
# ==============================================================================
# Skew:                          5.4878   Kurtosis:                      36.0466
# Centered skew:                 2.1311   Centered kurtosis:             31.4679
# ==============================================================================
# Removing rows by NA value
# No. of removed rows: 0
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:              DailyConfirmed   No. Observations:                 5300
# Model:                                 GEE   No. clusters:                       40
# Method:                        Generalized   Min. cluster size:                 105
#                       Estimating Equations   Max. cluster size:                 180
# Family:                            Poisson   Mean cluster size:               132.5
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Thu, 02 Jul 2020   Scale:                           1.000
# Covariance type:                    robust   Time:                         21:38:23
# ===============================================================================================
#                                   coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# Intercept                      -3.5026      3.192     -1.097      0.273      -9.760       2.755
# Days                           -0.0205      0.015     -1.406      0.160      -0.049       0.008
# logDays                         2.8339      1.009      2.809      0.005       0.857       4.811
# C4_Restrictionsongatherings     0.3952      0.378      1.047      0.295      -0.345       1.135
# ==============================================================================
# Skew:                          5.5492   Kurtosis:                      37.0067
# Centered skew:                 2.3186   Centered kurtosis:             33.2616
# ==============================================================================
# Removing rows by NA value
# No. of removed rows: 0
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:              DailyConfirmed   No. Observations:                 5300
# Model:                                 GEE   No. clusters:                       40
# Method:                        Generalized   Min. cluster size:                 105
#                       Estimating Equations   Max. cluster size:                 180
# Family:                            Poisson   Mean cluster size:               132.5
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Thu, 02 Jul 2020   Scale:                           1.000
# Covariance type:                    robust   Time:                         21:38:23
# ===========================================================================================
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                  -3.9417      3.174     -1.242      0.214     -10.162       2.279
# Days                       -0.0202      0.012     -1.712      0.087      -0.043       0.003
# logDays                     2.9311      0.931      3.147      0.002       1.106       4.757
# C5_Closepublictransport     0.6861      0.322      2.134      0.033       0.056       1.316
# ==============================================================================
# Skew:                          5.5242   Kurtosis:                      36.7476
# Centered skew:                 2.2791   Centered kurtosis:             32.7433
# ==============================================================================
# Removing rows by NA value
# No. of removed rows: 0
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:              DailyConfirmed   No. Observations:                 5300
# Model:                                 GEE   No. clusters:                       40
# Method:                        Generalized   Min. cluster size:                 105
#                       Estimating Equations   Max. cluster size:                 180
# Family:                            Poisson   Mean cluster size:               132.5
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Thu, 02 Jul 2020   Scale:                           1.000
# Covariance type:                    robust   Time:                         21:38:23
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                    -3.1852      3.328     -0.957      0.339      -9.708       3.337
# Days                         -0.0168      0.015     -1.139      0.255      -0.046       0.012
# logDays                       2.6549      1.068      2.486      0.013       0.562       4.748
# C6_Stayathomerequirements     0.8436      0.448      1.882      0.060      -0.035       1.722
# ==============================================================================
# Skew:                          5.5597   Kurtosis:                      37.2189
# Centered skew:                 2.3223   Centered kurtosis:             33.2429
# ==============================================================================
# Removing rows by NA value
# No. of removed rows: 0
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:              DailyConfirmed   No. Observations:                 5300
# Model:                                 GEE   No. clusters:                       40
# Method:                        Generalized   Min. cluster size:                 105
#                       Estimating Equations   Max. cluster size:                 180
# Family:                            Poisson   Mean cluster size:               132.5
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Thu, 02 Jul 2020   Scale:                           1.000
# Covariance type:                    robust   Time:                         21:38:23
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                            -3.3742      3.452     -0.977      0.328     -10.140       3.392
# Days                                 -0.0190      0.016     -1.206      0.228      -0.050       0.012
# logDays                               2.7705      1.113      2.489      0.013       0.589       4.952
# C7_Restrictionsoninternalmovement     0.4671      0.365      1.278      0.201      -0.249       1.183
# ==============================================================================
# Skew:                          5.5345   Kurtosis:                      36.8414
# Centered skew:                 2.3026   Centered kurtosis:             32.9717
# ==============================================================================
# Removing rows by NA value
# No. of removed rows: 0
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:              DailyConfirmed   No. Observations:                 5300
# Model:                                 GEE   No. clusters:                       40
# Method:                        Generalized   Min. cluster size:                 105
#                       Estimating Equations   Max. cluster size:                 180
# Family:                            Poisson   Mean cluster size:               132.5
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Thu, 02 Jul 2020   Scale:                           1.000
# Covariance type:                    robust   Time:                         21:38:24
# ==================================================================================================
#                                      coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         -3.9129      3.340     -1.172      0.241     -10.459       2.633
# Days                              -0.0226      0.015     -1.466      0.143      -0.053       0.008
# logDays                            2.9712      1.075      2.764      0.006       0.864       5.078
# C8_Internationaltravelcontrols     0.3270      0.461      0.709      0.478      -0.576       1.230
# ==============================================================================
# Skew:                          5.5234   Kurtosis:                      36.7691
# Centered skew:                 2.3072   Centered kurtosis:             33.0644
# ==============================================================================
# Removing rows by NA value
# No. of removed rows: 0
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:              DailyConfirmed   No. Observations:                 5300
# Model:                                 GEE   No. clusters:                       40
# Method:                        Generalized   Min. cluster size:                 105
#                       Estimating Equations   Max. cluster size:                 180
# Family:                            Poisson   Mean cluster size:               132.5
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Thu, 02 Jul 2020   Scale:                           1.000
# Covariance type:                    robust   Time:                         21:38:24
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           -4.2662      3.251     -1.312      0.189     -10.637       2.105
# Days                -0.0252      0.013     -1.900      0.057      -0.051       0.001
# logDays              3.1544      0.989      3.190      0.001       1.216       5.093
# E1_Incomesupport     0.0742      0.449      0.165      0.869      -0.806       0.955
# ==============================================================================
# Skew:                          5.5353   Kurtosis:                      36.6426
# Centered skew:                 2.2448   Centered kurtosis:             32.6513
# ==============================================================================
# Removing rows by NA value
# No. of removed rows: 0
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:              DailyConfirmed   No. Observations:                 5300
# Model:                                 GEE   No. clusters:                       40
# Method:                        Generalized   Min. cluster size:                 105
#                       Estimating Equations   Max. cluster size:                 180
# Family:                            Poisson   Mean cluster size:               132.5
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Thu, 02 Jul 2020   Scale:                           1.000
# Covariance type:                    robust   Time:                         21:38:24
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                -5.0577      3.556     -1.422      0.155     -12.028       1.913
# Days                     -0.0282      0.013     -2.127      0.033      -0.054      -0.002
# logDays                   3.4364      1.079      3.185      0.001       1.322       5.551
# E2_Debtcontractrelief    -0.2838      0.321     -0.884      0.377      -0.913       0.345
# ==============================================================================
# Skew:                          5.5057   Kurtosis:                      36.2804
# Centered skew:                 2.1993   Centered kurtosis:             32.0787
# ==============================================================================
# Removing rows by NA value
# No. of removed rows: 0
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:              DailyConfirmed   No. Observations:                 5300
# Model:                                 GEE   No. clusters:                       40
# Method:                        Generalized   Min. cluster size:                 105
#                       Estimating Equations   Max. cluster size:                 180
# Family:                            Poisson   Mean cluster size:               132.5
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Thu, 02 Jul 2020   Scale:                           1.000
# Covariance type:                    robust   Time:                         21:38:24
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept            -4.4191      3.191     -1.385      0.166     -10.673       1.834
# Days                 -0.0257      0.013     -2.026      0.043      -0.051      -0.001
# logDays               3.2069      0.958      3.347      0.001       1.329       5.085
# E3_Fiscalmeasures     0.0113      0.024      0.461      0.645      -0.037       0.059
# ==============================================================================
# Skew:                          5.5451   Kurtosis:                      36.7294
# Centered skew:                 2.2418   Centered kurtosis:             32.6755
# ==============================================================================
# Removing rows by NA value
# No. of removed rows: 0
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:              DailyConfirmed   No. Observations:                 5300
# Model:                                 GEE   No. clusters:                       40
# Method:                        Generalized   Min. cluster size:                 105
#                       Estimating Equations   Max. cluster size:                 180
# Family:                            Poisson   Mean cluster size:               132.5
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Thu, 02 Jul 2020   Scale:                           1.000
# Covariance type:                    robust   Time:                         21:38:24
# ===========================================================================================
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                  -4.3846      3.194     -1.373      0.170     -10.644       1.875
# Days                       -0.0256      0.013     -2.003      0.045      -0.051      -0.001
# logDays                     3.1968      0.961      3.328      0.001       1.314       5.080
# E4_Internationalsupport     0.0645      0.070      0.923      0.356      -0.072       0.201
# ==============================================================================
# Skew:                          5.5321   Kurtosis:                      36.6022
# Centered skew:                 2.2318   Centered kurtosis:             32.5500
# ==============================================================================
# Removing rows by NA value
# No. of removed rows: 0
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:              DailyConfirmed   No. Observations:                 5300
# Model:                                 GEE   No. clusters:                       40
# Method:                        Generalized   Min. cluster size:                 105
#                       Estimating Equations   Max. cluster size:                 180
# Family:                            Poisson   Mean cluster size:               132.5
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Thu, 02 Jul 2020   Scale:                           1.000
# Covariance type:                    robust   Time:                         21:38:24
# =================================================================================================
#                                     coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# Intercept                        -4.4897      3.374     -1.331      0.183     -11.102       2.122
# Days                             -0.0267      0.016     -1.673      0.094      -0.058       0.005
# logDays                           3.2665      1.103      2.962      0.003       1.105       5.428
# H1_Publicinformationcampaigns    -0.1118      0.430     -0.260      0.795      -0.955       0.731
# ==============================================================================
# Skew:                          5.5422   Kurtosis:                      36.6238
# Centered skew:                 2.2092   Centered kurtosis:             32.4150
# ==============================================================================
# Removing rows by NA value
# No. of removed rows: 0
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:              DailyConfirmed   No. Observations:                 5300
# Model:                                 GEE   No. clusters:                       40
# Method:                        Generalized   Min. cluster size:                 105
#                       Estimating Equations   Max. cluster size:                 180
# Family:                            Poisson   Mean cluster size:               132.5
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Thu, 02 Jul 2020   Scale:                           1.000
# Covariance type:                    robust   Time:                         21:38:25
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           -3.5935      3.412     -1.053      0.292     -10.282       3.095
# Days                -0.0224      0.015     -1.482      0.138      -0.052       0.007
# logDays              2.8340      1.148      2.468      0.014       0.583       5.085
# H2_Testingpolicy     0.8712      0.997      0.874      0.382      -1.083       2.825
# ==============================================================================
# Skew:                          5.4788   Kurtosis:                      37.0009
# Centered skew:                 2.3961   Centered kurtosis:             33.2640
# ==============================================================================
# Removing rows by NA value
# No. of removed rows: 0
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:              DailyConfirmed   No. Observations:                 5300
# Model:                                 GEE   No. clusters:                       40
# Method:                        Generalized   Min. cluster size:                 105
#                       Estimating Equations   Max. cluster size:                 180
# Family:                            Poisson   Mean cluster size:               132.5
# Dependence structure:         Independence   Num. iterations:                     3
# Date:                     Thu, 02 Jul 2020   Scale:                           1.000
# Covariance type:                    robust   Time:                         21:38:25
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept            -4.5515      3.281     -1.387      0.165     -10.982       1.878
# Days                 -0.0317      0.014     -2.220      0.026      -0.060      -0.004
# logDays               3.5334      1.042      3.390      0.001       1.490       5.576
# H3_Contacttracing    -1.4071      0.590     -2.383      0.017      -2.564      -0.250
# ==============================================================================
# Skew:                          5.3450   Kurtosis:                      34.9086
# Centered skew:                 1.9669   Centered kurtosis:             29.5448
# ==============================================================================
# Removing rows by NA value
# No. of removed rows: 0
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:              DailyConfirmed   No. Observations:                 5300
# Model:                                 GEE   No. clusters:                       40
# Method:                        Generalized   Min. cluster size:                 105
#                       Estimating Equations   Max. cluster size:                 180
# Family:                            Poisson   Mean cluster size:               132.5
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Thu, 02 Jul 2020   Scale:                           1.000
# Covariance type:                    robust   Time:                         21:38:25
# ======================================================================================================
#                                          coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                             -4.4630      3.217     -1.387      0.165     -10.769       1.843
# Days                                  -0.0257      0.013     -2.019      0.043      -0.051      -0.001
# logDays                                3.2163      0.965      3.333      0.001       1.325       5.108
# H4_Emergencyinvestmentinhealthcare     0.0422      0.024      1.785      0.074      -0.004       0.089
# ==============================================================================
# Skew:                          5.5457   Kurtosis:                      36.7479
# Centered skew:                 2.2428   Centered kurtosis:             32.6477
# ==============================================================================
# Removing rows by NA value
# No. of removed rows: 0
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:              DailyConfirmed   No. Observations:                 5300
# Model:                                 GEE   No. clusters:                       40
# Method:                        Generalized   Min. cluster size:                 105
#                       Estimating Equations   Max. cluster size:                 180
# Family:                            Poisson   Mean cluster size:               132.5
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Thu, 02 Jul 2020   Scale:                           1.000
# Covariance type:                    robust   Time:                         21:38:25
# ===========================================================================================
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                  -4.4068      3.188     -1.382      0.167     -10.654       1.841
# Days                       -0.0257      0.013     -2.022      0.043      -0.051      -0.001
# logDays                     3.2053      0.958      3.346      0.001       1.328       5.083
# H5_Investmentinvaccines    -0.0142      0.050     -0.283      0.777      -0.112       0.084
# ==============================================================================
# Skew:                          5.5434   Kurtosis:                      36.7060
# Centered skew:                 2.2398   Centered kurtosis:             32.6551
# ==============================================================================

# %%
simple_marker_result = pd.DataFrame.from_dict(variable_dict).transpose().sort_values(by=['pval'])
simple_marker_result.to_csv('simple_marker_with_days_log_GEE_result.csv',)
simple_marker_result
# Out:
#                                         coef      pval
# H3_Contacttracing                  -0.031698  0.026430
# E2_Debtcontractrelief              -0.028157  0.033452
# C3_Cancelpublicevents              -0.034428  0.041177
# E3_Fiscalmeasures                  -0.025702  0.042808
# H5_Investmentinvaccines            -0.025718  0.043156
# H4_Emergencyinvestmentinhealthcare -0.025721  0.043469
# E4_Internationalsupport            -0.025611  0.045200
# E1_Incomesupport                   -0.025201  0.057421
# C5_Closepublictransport            -0.020245  0.086978
# H1_Publicinformationcampaigns      -0.026689  0.094348
# H2_Testingpolicy                   -0.022408  0.138317
# C1_Schoolclosing                   -0.022990  0.138855
# C8_Internationaltravelcontrols     -0.022563  0.142756
# C4_Restrictionsongatherings        -0.020499  0.159713
# C7_Restrictionsoninternalmovement  -0.019018  0.227768
# C2_Workplaceclosing                -0.021784  0.230368
# C6_Stayathomerequirements          -0.016782  0.254529

# %%
fam = sm.families.Poisson()
ind = sm.cov_struct.Independence()

variable_dict = {}

# for variable in variables:
#     sub_data = data.loc[:,['DailyConfirmed', 'Days', 'CountryCode', variable]]
data = data.fillna(0)
data['logDays'] = np.log(data['Days'])
print("Removing rows by NA value")
print("No. of removed rows:", len(data['Days'])-len(data['Days']))
try:
    mod = smf.gee("DailyConfirmed ~  Days + logDays + "+ ' + '.join(variables[:4]) + ' + ' + ' + '.join(variables[5:]) , "CountryCode", data , cov_struct = ind, family = fam)
    res = mod.fit()
#         country_code = list(set(data['CountryCode']))

    pval = res.pvalues[1]
    coef = res.params[1]
    variable_dict[variable] = {'coef':coef, 'pval':pval, 'no.of countries':len(country_code)}
    print(res.summary())
#         for country in country_code[:1] :
    predict_country = data
    predicted = res.predict(predict_country)
    plt.plot(predict_country['Days'], predicted, '-')
    plt.plot(predict_country['Days'], predict_country['DailyConfirmed'], '-')
    plt.show()
except Exception as e:
    print(e)
    print("Failed to fit the model using", variable)
# Out:
# Removing rows by NA value
# No. of removed rows: 0
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:              DailyConfirmed   No. Observations:                 5300
# Model:                                 GEE   No. clusters:                       40
# Method:                        Generalized   Min. cluster size:                 105
#                       Estimating Equations   Max. cluster size:                 180
# Family:                            Poisson   Mean cluster size:               132.5
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Thu, 02 Jul 2020   Scale:                           1.000
# Covariance type:                    robust   Time:                         21:25:51
# ======================================================================================================
#                                          coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                             -3.7935      2.329     -1.629      0.103      -8.359       0.772
# Days                                  -0.0266      0.010     -2.576      0.010      -0.047      -0.006
# logDays                                3.1300      0.749      4.181      0.000       1.663       4.597
# C1_Schoolclosing                       0.0521      0.577      0.090      0.928      -1.079       1.184
# C2_Workplaceclosing                   -0.0203      0.872     -0.023      0.981      -1.729       1.688
# C3_Cancelpublicevents                 -1.9696      0.808     -2.438      0.015      -3.553      -0.386
# C4_Restrictionsongatherings           -0.1624      0.698     -0.233      0.816      -1.531       1.207
# C6_Stayathomerequirements              2.1968      0.756      2.908      0.004       0.716       3.678
# C7_Restrictionsoninternalmovement      0.3618      0.595      0.608      0.543      -0.804       1.528
# C8_Internationaltravelcontrols         0.0797      0.384      0.207      0.836      -0.673       0.833
# E1_Incomesupport                      -0.8509      0.823     -1.034      0.301      -2.464       0.762
# E2_Debtcontractrelief                 -0.1633      0.481     -0.339      0.735      -1.107       0.780
# E3_Fiscalmeasures                  -2.888e-05      0.026     -0.001      0.999      -0.051       0.051
# E4_Internationalsupport                0.0493      0.025      1.937      0.053      -0.001       0.099
# H1_Publicinformationcampaigns          0.6929      0.555      1.248      0.212      -0.396       1.781
# H2_Testingpolicy                       2.7467      1.002      2.742      0.006       0.783       4.710
# H3_Contacttracing                     -3.2906      0.573     -5.744      0.000      -4.413      -2.168
# H4_Emergencyinvestmentinhealthcare    -0.0060      0.020     -0.293      0.769      -0.046       0.034
# H5_Investmentinvaccines               -0.0918      0.051     -1.785      0.074      -0.193       0.009
# ==============================================================================
# Skew:                          4.8748   Kurtosis:                      41.0928
# Centered skew:                 3.2755   Centered kurtosis:             46.7912
# ==============================================================================

# %%
fam = sm.families.Poisson()
ind = sm.cov_struct.Independence()

variable_dict = {}

# for variable in variables:
#     sub_data = data.loc[:,['DailyConfirmed', 'Days', 'CountryCode', variable]]
data = data.fillna(0)
data['logDays'] = np.log(data['Days'])
print("Removing rows by NA value")
print("No. of removed rows:", len(data['Days'])-len(data['Days']))
try:
    mod = smf.gee("DailyConfirmed ~  Days + logDays + "+ ' + '.join(variables[:4]) + ' + ' + ' + '.join(variables[5:]) , "CountryCode", data , cov_struct = ind, family = fam)
    res = mod.fit()
#         country_code = list(set(data['CountryCode']))

    pval = res.pvalues[1]
    coef = res.params[1]
    variable_dict[variable] = {'coef':coef, 'pval':pval, 'no.of countries':len(country_code)}
    print(res.summary())
#         for country in country_code[:1] :
    predict_country = data
    predicted = res.predict(predict_country)
    cumulative = np.cumsum(predicted)
    plt.plot(predict_country['Days'][:-1], cumulative[:-1], '-')
    plt.plot(predict_country['Days'][:-1], predict_country['ConfirmedCases'][:-1], '-')
    plt.show()
except Exception as e:
    print(e)
    print("Failed to fit the model using", variable)
# Out:
# Removing rows by NA value
# No. of removed rows: 0
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:              DailyConfirmed   No. Observations:                  161
# Model:                                 GEE   No. clusters:                        1
# Method:                        Generalized   Min. cluster size:                 161
#                       Estimating Equations   Max. cluster size:                 161
# Family:                            Poisson   Mean cluster size:               161.0
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Thu, 02 Jul 2020   Scale:                           1.000
# Covariance type:                    robust   Time:                         02:42:49
# ======================================================================================================
#                                          coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                              5.9785   1.54e-14   3.88e+14      0.000       5.978       5.978
# Days                                  -0.0166   6.17e-17  -2.69e+14      0.000      -0.017      -0.017
# logDays                                1.3898   5.35e-15    2.6e+14      0.000       1.390       1.390
# C1_Schoolclosing                       0.8517   3.02e-13   2.82e+12      0.000       0.852       0.852
# C2_Workplaceclosing                   -0.9887   3.98e-15  -2.48e+14      0.000      -0.989      -0.989
# C3_Cancelpublicevents                 -1.5003        nan        nan        nan         nan         nan
# C4_Restrictionsongatherings            4.5226   9.13e-15   4.95e+14      0.000       4.523       4.523
# C6_Stayathomerequirements              0.7816   1.94e-14   4.03e+13      0.000       0.782       0.782
# C7_Restrictionsoninternalmovement     -2.7185   2.61e-14  -1.04e+14      0.000      -2.719      -2.719
# C8_Internationaltravelcontrols        -4.5946   2.83e-13  -1.62e+13      0.000      -4.595      -4.595
# E1_Incomesupport                       2.8165      0.008    334.228      0.000       2.800       2.833
# E2_Debtcontractrelief                  2.0941      0.011    186.375      0.000       2.072       2.116
# E3_Fiscalmeasures                     -0.9743   2.21e-15  -4.41e+14      0.000      -0.974      -0.974
# E4_Internationalsupport                0.0312   1.57e-16   1.98e+14      0.000       0.031       0.031
# H1_Publicinformationcampaigns          1.3115        nan        nan        nan         nan         nan
# H2_Testingpolicy                       6.8092        nan        nan        nan         nan         nan
# H3_Contacttracing                    -16.1553        nan        nan        nan         nan         nan
# H4_Emergencyinvestmentinhealthcare     1.0174   2.55e-15      4e+14      0.000       1.017       1.017
# H5_Investmentinvaccines               -0.0056   2.01e-16  -2.79e+13      0.000      -0.006      -0.006
# ==============================================================================
# Skew:                         -1.1358   Kurtosis:                      16.0128
# Centered skew:                -1.1358   Centered kurtosis:             16.0128
# ==============================================================================
# /home/twgoo/miniconda3/lib/python3.7/site-packages/statsmodels/genmod/generalized_estimating_equations.py:1852: RuntimeWarning: invalid value encountered in sqrt
#   return np.sqrt(np.diag(self.cov_robust))
# /home/twgoo/miniconda3/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in greater
#   return (a < x) & (x < b)
# /home/twgoo/miniconda3/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py:903: RuntimeWarning: invalid value encountered in less
#   return (a < x) & (x < b)
# /home/twgoo/miniconda3/lib/python3.7/site-packages/scipy/stats/_distn_infrastructure.py:1912: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= _a)

# %%
# Out:
#                                         coef      pval  no.of countries
# H3_Contacttracing                  -0.031698  0.026430             40.0
# E2_Debtcontractrelief              -0.028157  0.033452             40.0
# C3_Cancelpublicevents              -0.034428  0.041177             40.0
# E3_Fiscalmeasures                  -0.025702  0.042808             40.0
# H5_Investmentinvaccines            -0.025718  0.043156             40.0
# H4_Emergencyinvestmentinhealthcare -0.025721  0.043469             40.0
# E4_Internationalsupport            -0.025611  0.045200             40.0
# E1_Incomesupport                   -0.025201  0.057421             40.0
# C5_Closepublictransport            -0.020245  0.086978             40.0
# H1_Publicinformationcampaigns      -0.026689  0.094348             40.0
# H2_Testingpolicy                   -0.022408  0.138317             40.0
# C1_Schoolclosing                   -0.022990  0.138855             40.0
# C8_Internationaltravelcontrols     -0.022563  0.142756             40.0
# C4_Restrictionsongatherings        -0.020499  0.159713             40.0
# C7_Restrictionsoninternalmovement  -0.019018  0.227768             40.0
# C2_Workplaceclosing                -0.021784  0.230368             40.0
# C6_Stayathomerequirements          -0.016782  0.254529             40.0

# %%
# Out:
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:              DailyConfirmed   No. Observations:                  458
# Model:                                 GEE   No. clusters:                        3
# Method:                        Generalized   Min. cluster size:                 150
#                       Estimating Equations   Max. cluster size:                 157
# Family:                            Poisson   Mean cluster size:               152.7
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Wed, 01 Jul 2020   Scale:                           1.000
# Covariance type:                    robust   Time:                         15:24:42
# ==================================================================================================
#                                      coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                         -8.3165      1.913     -4.346      0.000     -12.067      -4.566
# Days                              -0.0456      0.002    -19.775      0.000      -0.050      -0.041
# logDays                            4.2524      0.405     10.507      0.000       3.459       5.046
# C1_Schoolclosing                   0.3147      0.935      0.337      0.736      -1.518       2.147
# C2_Workplaceclosing               -0.2859      1.823     -0.157      0.875      -3.858       3.286
# C4_Restrictionsongatherings        2.6699      1.736      1.538      0.124      -0.733       6.073
# C6_Stayathomerequirements          1.1526      1.472      0.783      0.434      -1.732       4.037
# C8_Internationaltravelcontrols    -4.8672      1.043     -4.667      0.000      -6.911      -2.823
# ==============================================================================
# Skew:                          1.3770   Kurtosis:                      20.0126
# Centered skew:                 0.8323   Centered kurtosis:             20.2828
# ==============================================================================

# %%
korea_dat = total_dat[total_dat['CountryCode']=='GBR']
predicted = res.predict(korea_dat)

plt.plot(korea_dat['Days'], predicted, '-')
plt.plot(korea_dat['Days'], korea_dat['DailyConfirmed'], '-')

# %%
korea_dat = total_dat[total_dat['CountryCode']=='AUS']
predicted = res.predict(korea_dat)

plt.plot(korea_dat['Days'], predicted, '-')
plt.plot(korea_dat['Days'], korea_dat['DailyConfirmed'], '-')

# %%
mod = smf.gee("DailyConfirmed ~  Days + logDays + C1_Schoolclosing + C2_Workplaceclosing + C4_Restrictionsongatherings + C6_Stayathomerequirements + C8_Internationaltravelcontrols", "CountryCode", korea_dat , cov_struct = ind, family = fam)

# %%
res = mod.fit()
print(res.summary())
# Out:
#                                GEE Regression Results
# ===================================================================================
# Dep. Variable:              DailyConfirmed   No. Observations:                  150
# Model:                                 GEE   No. clusters:                        1
# Method:                        Generalized   Min. cluster size:                 150
#                       Estimating Equations   Max. cluster size:                 150
# Family:                            Poisson   Mean cluster size:               150.0
# Dependence structure:         Independence   Num. iterations:                     2
# Date:                     Wed, 01 Jul 2020   Scale:                           1.000
# Covariance type:                    robust   Time:                         15:09:26
# ==================================================================================================
#                                      coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                          2.0905   2.36e-14   8.87e+13      0.000       2.090       2.090
# Days                               0.0228   2.17e-16   1.05e+14      0.000       0.023       0.023
# logDays                           -1.6375   1.33e-14  -1.23e+14      0.000      -1.637      -1.637
# C1_Schoolclosing                  10.2291   1.65e-14    6.2e+14      0.000      10.229      10.229
# C2_Workplaceclosing               -2.5606    4.6e-15  -5.56e+14      0.000      -2.561      -2.561
# C4_Restrictionsongatherings        3.6110   7.35e-16   4.91e+15      0.000       3.611       3.611
# C6_Stayathomerequirements         -2.1504   4.11e-15  -5.23e+14      0.000      -2.150      -2.150
# C8_Internationaltravelcontrols    -2.9157   2.23e-15   -1.3e+15      0.000      -2.916      -2.916
# ==============================================================================
# Skew:                          2.1331   Kurtosis:                      11.3745
# Centered skew:                 2.1331   Centered kurtosis:             11.3745
# ==============================================================================

# %%
predicted = res.predict(korea_dat)
plt.plot(korea_dat['Days'], predicted, '-')
plt.plot(korea_dat['Days'], korea_dat['DailyConfirmed'], '-')
